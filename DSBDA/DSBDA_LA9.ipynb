# %% [markdown]
# # Importing Required Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Karunya\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Karunya\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %% [markdown]
# # Loading the Dataset

# %%
df = sns.load_dataset('titanic')
print(f"titanic dataset loaded into DataFrame df, having shape {df.shape}")
# Out:
# titanic dataset loaded into DataFrame df, having shape (891, 15)

# %% [markdown]
# # Exploring the Dataset

# %% [markdown]
# ## Dimension and Size

# %%
print(f"No. of Rows : {df.shape[0]}\nNo. of Columns : {df.shape[1]}\nTotal Number of Cells : {df.size}")
# Out:
# No. of Rows : 891
# No. of Columns : 15
# Total Number of Cells : 13365

# %% [markdown]
# ## Displaying Sample Values

# %%
print("Top 5 values")
display(df.head())
# Out:
# Top 5 values
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print("Last 5 values")
display(df.tail())
# Out:
# Last 5 values
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print("Randomly selected 5 values")
display(df.sample(5))
# Out:
# Randomly selected 5 values
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 295         0       1    male   NaN      0      0  27.7208        C   First
# 835         1       1  female  39.0      1      1  83.1583        C   First
# 675         0       3    male  18.0      0      0   7.7750        S   Third
# 509         1       3    male  26.0      0      0  56.4958        S   Third
# 150         0       2    male  51.0      0      0  12.5250        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 295    man        True  NaN    Cherbourg    no   True
# 835  woman       False    E    Cherbourg   yes  False
# 675    man        True  NaN  Southampton    no   True
# 509    man        True  NaN  Southampton   yes   True
# 150    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Metadata

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %% [markdown]
# ## Statistical Summary

# %%
display(df.describe())
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Identifying NULL Values

# %%
display(df.isnull())
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
print(f"No. of NULL Values per Column\n{df.isnull().sum()}\n-------------------------------\nTotal No. of NULL Values : {df.isnull().sum().sum()}")
# Out:
# No. of NULL Values per Column
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
# -------------------------------
# Total No. of NULL Values : 869

# %% [markdown]
# ## Imputing NULL Values

# %%
df['age'] = df['age'].fillna(df['age'].median())

# %%
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])
df['embarked_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])

# %%
df.drop(columns=['deck'], inplace=True)

# %% [raw]
# we dropped 'deck' feature as 688/891 values were missing, so imputing them might've led to wrong analysis

# %%
print(f"No. of NULL Values per Column\n{df.isnull().sum()}\n-------------------------------\nTotal No. of NULL Values : {df.isnull().sum().sum()}")
# Out:
# No. of NULL Values per Column
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# embarked_town    0
# dtype: int64
# -------------------------------
# Total No. of NULL Values : 2

# %% [markdown]
# ## Detecting Outliers

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='age', data=df, color='skyblue')
plt.title('Boxplot of Age (Outlier Detection)')
plt.xlabel('Age')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Converting to Suitable DataTypes

# %%
display(df.dtypes)
# Out:
# survived            int64
# pclass              int64
# sex                object
# age               float64
# sibsp               int64
# parch               int64
# fare              float64
# embarked           object
# class            category
# who                object
# adult_male           bool
# embark_town        object
# alive              object
# alone                bool
# embarked_town      object
# dtype: object

# %%
print("Memory Usage Before Converting to Category Columns")
df.memory_usage(deep=True).sum()
# Out:
# Memory Usage Before Converting to Category Columns
# np.int64(337106)

# %%
display(df.nunique())
# Out:
# survived           2
# pclass             3
# sex                2
# age               88
# sibsp              7
# parch              7
# fare             248
# embarked           3
# class              3
# who                3
# adult_male         2
# embark_town        3
# alive              2
# alone              2
# embarked_town      3
# dtype: int64

# %%
cat_cols = df.columns[df.nunique() <= 5] #Only selecting features with unique values less than 5
df[cat_cols] = df[cat_cols].astype('category')

# %%
display(df.dtypes)
# Out:
# survived         category
# pclass           category
# sex              category
# age               float64
# sibsp               int64
# parch               int64
# fare              float64
# embarked         category
# class            category
# who              category
# adult_male       category
# embark_town      category
# alive            category
# alone            category
# embarked_town    category
# dtype: object

# %%
print("Memory Usage After Converting to Category Columns")
df.memory_usage(deep=True).sum()
# Out:
# Memory Usage After Converting to Category Columns
# np.int64(40659)

# %% [markdown]
# # Quick EDA

# %% [markdown]
# ## Univariate Analysis

# %%
df['age'].hist(bins=20)
plt.title('Histogram of Age')
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %%
sns.countplot(x='sex', data=df, hue='sex')
plt.title('Count of Sex')
# Out:
# Text(0.5, 1.0, 'Count of Sex')

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.countplot(x='sex', hue='survived', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='survived', y='age', data=df, hue='survived')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.violinplot(x='survived', y='age', data=df, hue='survived')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
plt.figure(figsize=(15,10))
sns.swarmplot(x='survived', y='age', data=df, hue='survived')
plt.show()
# Out:
# C:\Users\Karunya\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 5.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Karunya\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 14.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## KDE Plot

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data=df, x='age', fill=True, hue='survived')
plt.show()

# %%
survived_count = df[df['survived'] == 0].groupby('sex').size()
print(f"No. of People who did not Survive:\n{survived_count}")
# Out:
# No. of People who did not Survive:
# sex
# female     81
# male      468
# dtype: int64
# C:\Users\Karunya\AppData\Local\Temp\ipykernel_6520\2193719018.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survived_count = df[df['survived'] == 0].groupby('sex').size()

# %% [markdown]
# ## Correlation Heat Map

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >
